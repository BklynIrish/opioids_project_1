# %%
# Dependencies
#from census import Census
#from config import (census_key, gkey)
import gmaps
import numpy as np
import pandas as pd
import requests
from us import states
from scipy.stats import linregress
from matplotlib import pyplot as plt

# %%
cdc_data = pd.read_csv("./VSRR_Provisional_Drug_Overdose_Death_Counts.csv")
cdc_data.head()
# Out:
#   State  Year  Month           Period  \
# 0    AK  2015  April  12 month-ending
# 1    AK  2015  April  12 month-ending
# 2    AK  2015  April  12 month-ending
# 3    AK  2015  April  12 month-ending
# 4    AK  2015  April  12 month-ending
#
#                                            Indicator  Data Value  \
# 0         Synthetic opioids, excl. methadone (T40.4)         NaN
# 1                                   Number of Deaths      4133.0
# 2  Natural, semi-synthetic, & synthetic opioids, ...         NaN
# 3                                  Methadone (T40.3)         NaN
# 4                                     Heroin (T40.1)         NaN
#
#   Percent Complete  Percent Pending Investigation State Name  \
# 0              100                            0.0     Alaska
# 1              100                            0.0     Alaska
# 2              100                            0.0     Alaska
# 3              100                            0.0     Alaska
# ...

# %%
cdc_df = cdc_data[["Indicator", "State","Year", "Month", "Data Value","Percent Complete", "Percent Pending Investigation", "State Name", "Predicted Value"]]
cdc_df.head()
# Out:
#                                            Indicator State  Year  Month  \
# 0         Synthetic opioids, excl. methadone (T40.4)    AK  2015  April
# 1                                   Number of Deaths    AK  2015  April
# 2  Natural, semi-synthetic, & synthetic opioids, ...    AK  2015  April
# 3                                  Methadone (T40.3)    AK  2015  April
# 4                                     Heroin (T40.1)    AK  2015  April
#
#    Data Value Percent Complete  Percent Pending Investigation State Name  \
# 0         NaN              100                            0.0     Alaska
# 1      4133.0              100                            0.0     Alaska
# 2         NaN              100                            0.0     Alaska
# 3         NaN              100                            0.0     Alaska
# 4         NaN              100                            0.0     Alaska
#
#    Predicted Value
# 0              NaN
# 1              NaN
# 2              NaN
# ...

# %%
cdc_opiod_df = cdc_df.loc[cdc_df ["Indicator"]=="Opioids (T40.0-T40.4,T40.6)",:]
cdc_opiod_df
# Out:
#                          Indicator State  Year      Month  Data Value  \
# 11     Opioids (T40.0-T40.4,T40.6)    AK  2015      April         NaN
# 12     Opioids (T40.0-T40.4,T40.6)    AK  2015     August         NaN
# 25     Opioids (T40.0-T40.4,T40.6)    AK  2015   December         NaN
# 37     Opioids (T40.0-T40.4,T40.6)    AK  2015   February         NaN
# 57     Opioids (T40.0-T40.4,T40.6)    AK  2015    January         NaN
# ...                            ...   ...   ...        ...         ...
# 31083  Opioids (T40.0-T40.4,T40.6)    YC  2019      March      1156.0
# 31098  Opioids (T40.0-T40.4,T40.6)    YC  2019        May      1135.0
# 31105  Opioids (T40.0-T40.4,T40.6)    YC  2019   November      1202.0
# 31124  Opioids (T40.0-T40.4,T40.6)    YC  2019    October      1173.0
# 31134  Opioids (T40.0-T40.4,T40.6)    YC  2019  September      1150.0
#
#       Percent Complete  Percent Pending Investigation     State Name  \
# ...
